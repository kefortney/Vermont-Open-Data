# %%
# %matplotlib inline

# Handle table-like data and matrices
import numpy as np
import pandas as pd

# Visualisation
import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# %% [markdown]
# Baby Names from Social Security Card Applications-National Level Data. The data (name, year of birth, sex and number) are from a 100 percent sample of Social Security card applications after 1879.

# %%
wholedf = pd.read_csv('Baby_Names_1880-2014.csv')

# %%
wholedf.head(5)
# Out:
#         Name Gender  Count       Year  Year Rank  month  day  year
# 0       Mary      F   7065 1880-01-01          1      1    1  1880
# 1       Anna      F   2604 1880-01-01          2      1    1  1880
# 2       Emma      F   2003 1880-01-01          3      1    1  1880
# 3  Elizabeth      F   1939 1880-01-01          4      1    1  1880
# 4     Minnie      F   1746 1880-01-01          5      1    1  1880

# %%
wholedf['Year'] = pd.to_datetime(wholedf['Year'])
wholedf['month'] = wholedf['Year'].dt.month
wholedf['day'] = wholedf['Year'].dt.day
wholedf['year'] = wholedf['Year'].dt.year

# %%
maledf = wholedf[(wholedf['Gender'] == "M")]
femaledf = wholedf[(wholedf['Gender'] == "F")]

# %%
uniquenames = pd.unique(maledf['Name'])
uniquenames.shape
# Out:
# (39199,)

# %%
uniquenames = pd.unique(femaledf['Name'])
uniquenames.shape
# Out:
# (64911,)

# %% [markdown]
# There are more unique female names compared to male

# %%
maledf[['Name', 'Count']].groupby(['Name'], as_index=False).sum().sort_values(by='Count',ascending=0)
# Out:
#               Name    Count
# 16388        James  5105919
# 18397         John  5084943
# 30763       Robert  4796695
# 25820      Michael  4309198
# 37547      William  4055473
# 8290         David  3577704
# 18801       Joseph  2570095
# 30531      Richard  2555330
# 5977       Charles  2364332
# 35095       Thomas  2283080
# 6317   Christopher  1994742
# 7821        Daniel  1868775
# 25256      Matthew  1553203
# 13085       George  1454503
# 9999        Donald  1408943
# 2116       Anthony  1403114
# 28649         Paul  1381037
# 24789         Mark  1343752
# 10872       Edward  1281204
# 33672       Steven  1273124
# 20783      Kenneth  1266821
# 1876        Andrew  1255892
# 18845       Joshua  1174787
# 4678         Brian  1157966
# 21014        Kevin  1153154
# 31029       Ronald  1075785
# 35270      Timothy  1060611
# 16903        Jason  1014584
# 17517      Jeffrey   970232
# 12609        Frank   907417
# ...            ...      ...
# 32521     Shamaine        5
# 4709       Brienne        5
# 22244       Kypten        5
# 22219       Kymeir        5
# 12541       Forbus        5
# 32571     Shandale        5
# 32570     Shanchez        5
# 4723          Brij        5
# 32563      Shamuel        5
# 12536        Fonza        5
# 32560      Shamori        5
# 12535      Fontane        5
# 22236     Kyntrell        5
# 22240       Kyonne        5
# 22242      Kyosuke        5
# 32543      Shamiek        5
# 32522      Shamair        5
# 22245       Kyptin        5
# 4729        Brilen        5
# 32538       Shamek        5
# 32537      Shameik        5
# 12529        Folke        5
# 4733       Brilynn        5
# 12527      Foister        5
# 4735         Brina        5
# 4737       Brindin        5
# 32528     Shamaree        5
# 22256        Kyrek        5
# 4739         Brink        5
# 39198        Zzyzx        5
#
# [39199 rows x 2 columns]

# %%
maledf.head()
# Out:
#            Name Gender  Count       Year  Year Rank  month  day  year
# 518397     John      M   9655 1880-01-01          1      1    1  1880
# 518398  William      M   9532 1880-01-01          2      1    1  1880
# 518399    James      M   5927 1880-01-01          3      1    1  1880
# 518400  Charles      M   5348 1880-01-01          4      1    1  1880
# 518401   George      M   5126 1880-01-01          5      1    1  1880

# %%
maletopdf = maledf[(maledf['Year Rank'] < 10)]
femaletopdf = femaledf[(femaledf['Year Rank'] < 10)]

# %%
maletopdf.shape
maletopdf.head()
# Out:
#            Name Gender  Count       Year  Year Rank  month  day  year
# 518397     John      M   9655 1880-01-01          1      1    1  1880
# 518398  William      M   9532 1880-01-01          2      1    1  1880
# 518399    James      M   5927 1880-01-01          3      1    1  1880
# 518400  Charles      M   5348 1880-01-01          4      1    1  1880
# 518401   George      M   5126 1880-01-01          5      1    1  1880

# %%
uniquename = pd.unique(maletopdf['Name'])
uniquename.shape
# Out:
# (41,)

# %%
sns.stripplot(x='Year', y='Name', hue='Year Rank', data=maletopdf)

# %%
uniquename = pd.unique(femaletopdf['Name'])
uniquename.shape
# Out:
# (73,)

# %%
sns.stripplot(x='Year', y='Name', hue='Year Rank', data=femaletopdf)

# %%
femaletopdf[(femaletopdf['Name'] == "Sharon")]
# Out:
#           Name Gender  Count       Year  Year Rank  month  day  year
# 217120  Sharon      F  24708 1943-01-01          8      1    1  1943
# 222485  Sharon      F  22428 1944-01-01          9      1    1  1944
# 227729  Sharon      F  20832 1945-01-01          8      1    1  1945
# 232973  Sharon      F  27823 1946-01-01          9      1    1  1946
# 238659  Sharon      F  28536 1947-01-01          9      1    1  1947
# 244764  Sharon      F  26137 1948-01-01          9      1    1  1948

# %%
femaletopdf[(femaletopdf['Year'] == "1980")]
# Out:
#              Name Gender  Count       Year  Year Rank  month  day  year
# 506240   Jennifer      F  58385 1980-01-01          1      1    1  1980
# 506241     Amanda      F  35820 1980-01-01          2      1    1  1980
# 506242    Jessica      F  33920 1980-01-01          3      1    1  1980
# 506243    Melissa      F  31631 1980-01-01          4      1    1  1980
# 506244      Sarah      F  25741 1980-01-01          5      1    1  1980
# 506245    Heather      F  19971 1980-01-01          6      1    1  1980
# 506246     Nicole      F  19916 1980-01-01          7      1    1  1980
# 506247        Amy      F  19832 1980-01-01          8      1    1  1980
# 506248  Elizabeth      F  19528 1980-01-01          9      1    1  1980

# %%
maletopdf[(maletopdf['Year'] == "1981")]
# Out:
#                Name Gender  Count       Year  Year Rank  month  day  year
# 895316      Michael      M  68752 1981-01-01          1      1    1  1981
# 895317  Christopher      M  50229 1981-01-01          2      1    1  1981
# 895318      Matthew      M  43323 1981-01-01          3      1    1  1981
# 895319        Jason      M  41921 1981-01-01          4      1    1  1981
# 895320        David      M  40643 1981-01-01          5      1    1  1981
# 895321       Joshua      M  39054 1981-01-01          6      1    1  1981
# 895322        James      M  38301 1981-01-01          7      1    1  1981
# 895323         John      M  34877 1981-01-01          8      1    1  1981
# 895324       Robert      M  34388 1981-01-01          9      1    1  1981

# %%
kendallm = wholedf[(wholedf['Name'] == "Kendall") & (wholedf['Gender'] == "M")]
kendallf = wholedf[(wholedf['Name'] == "Kendall") & (wholedf['Gender'] == "F")]

# %%
plt.plot(kendallm.Count)
plt.plot(kendallf.Count)

# %%
kendallf
# Out:
#             Name Gender  Count       Year  Year Rank  month  day  year
# 151520   Kendall      F      5 1929-01-01       4936      1    1  1929
# 190381   Kendall      F      7 1937-01-01       3629      1    1  1937
# 206329   Kendall      F      5 1940-01-01       4707      1    1  1940
# 210428   Kendall      F      7 1941-01-01       3781      1    1  1941
# 215664   Kendall      F      7 1942-01-01       3931      1    1  1942
# 219607   Kendall      F     14 1943-01-01       2495      1    1  1943
# 226366   Kendall      F      7 1944-01-01       3890      1    1  1944
# 230008   Kendall      F     15 1945-01-01       2287      1    1  1945
# 241050   Kendall      F     18 1947-01-01       2400      1    1  1947
# 247813   Kendall      F     12 1948-01-01       3058      1    1  1948
# 254077   Kendall      F     11 1949-01-01       3285      1    1  1949
# 259829   Kendall      F     13 1950-01-01       2974      1    1  1950
# 266576   Kendall      F     10 1951-01-01       3609      1    1  1951
# 272301   Kendall      F     13 1952-01-01       3121      1    1  1952
# 280369   Kendall      F      7 1953-01-01       4797      1    1  1953
# 285021   Kendall      F     15 1954-01-01       2955      1    1  1954
# 292150   Kendall      F     12 1955-01-01       3475      1    1  1955
# 297338   Kendall      F     31 1956-01-01       1941      1    1  1956
# 304141   Kendall      F     35 1957-01-01       1854      1    1  1957
# 310576   Kendall      F     69 1958-01-01       1278      1    1  1958
# 317561   Kendall      F     75 1959-01-01       1240      1    1  1959
# 324549   Kendall      F    109 1960-01-01       1035      1    1  1960
# 332218   Kendall      F     67 1961-01-01       1370      1    1  1961
# 339740   Kendall      F     66 1962-01-01       1364      1    1  1962
# 347315   Kendall      F     67 1963-01-01       1357      1    1  1963
# 354585   Kendall      F    120 1964-01-01        967      1    1  1964
# 362334   Kendall      F    122 1965-01-01        914      1    1  1965
# 370081   Kendall      F     89 1966-01-01       1127      1    1  1966
# 377692   Kendall      F     88 1967-01-01       1124      1    1  1967
# 385556   Kendall      F     89 1968-01-01       1139      1    1  1968
# ...          ...    ...    ...        ...        ...    ...  ...   ...
# 961643   Kendall      F    447 1985-01-01        472      1    1  1985
# 981673   Kendall      F    509 1986-01-01        427      1    1  1986
# 1002229  Kendall      F    702 1987-01-01        343      1    1  1987
# 1023692  Kendall      F    572 1988-01-01        411      1    1  1988
# 1046036  Kendall      F    623 1989-01-01        397      1    1  1989
# 1069812  Kendall      F    642 1990-01-01        406      1    1  1990
# 1094505  Kendall      F    667 1991-01-01        386      1    1  1991
# 1119573  Kendall      F    746 1992-01-01        350      1    1  1992
# 1144856  Kendall      F   1270 1993-01-01        217      1    1  1993
# 1170775  Kendall      F   1648 1994-01-01        179      1    1  1994
# 1196783  Kendall      F   1545 1995-01-01        190      1    1  1995
# 1222871  Kendall      F   1468 1996-01-01        198      1    1  1996
# 1249285  Kendall      F   1559 1997-01-01        193      1    1  1997
# 1276244  Kendall      F   1644 1998-01-01        187      1    1  1998
# 1304165  Kendall      F   1442 1999-01-01        217      1    1  1999
# 1332683  Kendall      F   1650 2000-01-01        191      1    1  2000
# 1362463  Kendall      F   1524 2001-01-01        208      1    1  2001
# 1392711  Kendall      F   1642 2002-01-01        195      1    1  2002
# 1423232  Kendall      F   2182 2003-01-01        156      1    1  2003
# 1454386  Kendall      F   2359 2004-01-01        137      1    1  2004
# 1486416  Kendall      F   2456 2005-01-01        132      1    1  2005
# 1518965  Kendall      F   2322 2006-01-01        148      1    1  2006
# 1553052  Kendall      F   2163 2007-01-01        166      1    1  2007
# 1587966  Kendall      F   2308 2008-01-01        149      1    1  2008
# 1622995  Kendall      F   2414 2009-01-01        133      1    1  2009
# 1657679  Kendall      F   2335 2010-01-01        133      1    1  2010
# 1691711  Kendall      F   2591 2011-01-01        124      1    1  2011
# 1725572  Kendall      F   2622 2012-01-01        116      1    1  2012
# 1759270  Kendall      F   2509 2013-01-01        130      1    1  2013
# 1792474  Kendall      F   2432 2014-01-01        131      1    1  2014
#
# [76 rows x 8 columns]

# %%
name = "Austin"
namem = wholedf[(wholedf['Name'] == name) & (wholedf['Gender'] == "M")]
namef = wholedf[(wholedf['Name'] == name) & (wholedf['Gender'] == "F")]

# %%
plt.plot(namem.Count)
plt.plot(namef.Count)

# %%
small = wholedf[(wholedf['year']) == 2010]
small.shape
# Out:
# (34041, 8)
